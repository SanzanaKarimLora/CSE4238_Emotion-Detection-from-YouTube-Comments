# %%
from google.colab import drive
drive.mount('/content/drive')
main_directory = '/content/drive/My Drive/My Tasks/Youtube/Emotion.csv'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv(main_directory,encoding = 'utf-8',sep=';')

df.head()
# Out:
#      id                                               text  ... lan       domain
# 0  2275       Hands down. You are good. I mean smart good.  ...  EN  funny_video
# 1  2283                     Your are very good. keep it up  ...  EN  funny_video
# 2  2292  Man!! I will never get used to these videos of...  ...  EN  funny_video
# 3  2293                                    ডিসলাইক দেয়া 32  ...  BN  funny_video
# 4  2298                                     ব্যাপক বিনোদন।  ...  BN  funny_video
#
# [5 rows x 5 columns]

# %%
# Get indexes where name column has value john
indexNames = df[(df['lan'] == 'EN') | (df['lan'] == 'BN')].index

# Delete these row indexes from dataFrame
df = df.drop(indexNames)

# %%
import logging
import pandas as pd
import numpy as np
from numpy import random
import gensim
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import re
from bs4 import BeautifulSoup
# %matplotlib inline

# %%
df = df[pd.notnull(df['emotion'])]
print(df.head(10))
print(df['text'].apply(lambda x: len(x.split(' '))).sum())
# Out:
#       id                                               text  ... lan       domain
# 5   2299                              Osadharon chaliye jao  ...  RN  funny_video
# 6   2304                     Shakil Ahmed otai to asol moza  ...  RN  funny_video
# 10  2387                                     Ore moja paisi  ...  RN  funny_video
# 15  2490  Dear Rahat Bro Next Video'r Jnno Aro Koto Din ...  ...  RN  funny_video
# 19  2543                     ei video te 1m view howa uchit  ...  RN  funny_video
# 24  2605                                 hahahahihihihohoho  ...  RN  funny_video
# 26  2704                                orreh buzz reh! x'D  ...  RN  funny_video
# 27  2716     Bro please , এত্তো গ্যাপ দিয়েন না, পর পর ছাড়েন  ...  RN  funny_video
# 28  2716     Bro please , এত্তো গ্যাপ দিয়েন না, পর পর ছাড়েন  ...  RN  funny_video
# 29  2774  eita best ! bro "gaaaaaaay" bole je cartoon ta...  ...  RN  funny_video
#
# [10 rows x 5 columns]
# 10247

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
#STOPWORDS = set(stopwords.words('english'))

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = BeautifulSoup(text, "lxml").text # HTML decoding
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    #text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwors from text
    text = ' '.join(word for word in text.split())
    return text
    
df['text'] = df['text'].apply(clean_text)

# %%
df['text'].apply(lambda x: len(x.split(' '))).sum()
# Out:
# 8756

# %%
X = df.text
y = df.emotion
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer

nb = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB()),
              ])
nb.fit(X_train, y_train)


from sklearn.metrics import classification_report
y_pred = nb.predict(X_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
#print(classification_report(y_test, y_pred,target_names=my_tags))
# Out:
# accuracy 0.5058479532163743

# %%
from sklearn.linear_model import LogisticRegression

logreg = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', LogisticRegression(n_jobs=1, C=1e5)),
               ])
logreg.fit(X_train, y_train)


y_pred = logreg.predict(X_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
#print(classification_report(y_test, y_pred,target_names=my_tags))
# Out:
# accuracy 0.5
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.33      0.43      0.37        30
#      disgust       0.47      0.38      0.42        77
#         fear       0.00      0.00      0.00         1
#          joy       0.60      0.70      0.65       105
#         none       0.60      0.56      0.58        87
#          sad       0.23      0.12      0.16        25
#     surprise       0.16      0.24      0.19        17
#
#     accuracy                           0.50       342
#    macro avg       0.34      0.35      0.34       342
# weighted avg       0.50      0.50      0.49       342
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
